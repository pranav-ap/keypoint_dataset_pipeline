# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Visualize

# %%
from Painter import Painter
from config import config

config
# Out:
# {'components': {'detector': 'dedode', 'matcher': 'roma'}, 'task': {'name': 'basalt', 'consider_samples': True, 'limit_count': 10, 'dataset': 'monado_slam', 'track': 'MOO07/MOO07_mapping_easy', 'cam': 'cam0'}, 'samples': {'samples': {'reference': 'sacre_coeur_A.jpg', 'target': 'sacre_coeur_B.jpg'}, 'basalt': {'reference': 8657652230990, 'target': 8657685519990}}, 'paths': {'roots': {'ws': '/home/stud/ath/ath_ws', 'mav': '${paths.roots.ws}/datasets/${task.dataset}/${task.track}/mav0', 'project': '${paths.roots.ws}/keypoint_dataset_pipeline', 'output': '${paths.roots.project}/output'}, 'samples': {'images_dir': '${paths.roots.project}/data/samples/images', 'tensors_dir': '${paths.roots.output}/tensors/samples'}, 'basalt': {'csv': '${paths.roots.mav}/${task.cam}/data.csv', 'images_dir': '${paths.roots.mav}/${task.cam}/data', 'tensors_dir': '${paths.roots.output}/tensors/${task.name}/${task.track}/${task.cam}', 'zip_dir': '${paths.roots.output}/zips/${task.name}/${task.track}/${task.cam}'}}, 'image': {'image_shape': [504, 504], 'patch_shape': [84, 84]}, 'dedode': {'batch_size': 6, 'image_keypoints_count': 300, 'patch_keypoints_count': 2, 'filter': {'images_sample_count': 100, 'patches_sample_count': 10}}, 'roma': {'filter': {'confidence_threshold': 0.6}}}

# %%
name_a, name_b = config.samples[config.task.name].reference, config.samples[config.task.name].target
name_a, name_b
# Out:
# (8657652230990, 8657685519990)

# %%
Painter.show_patches(name_a)
# Out:
# num_rows, num_cols (6, 6)
# patch_height, patch_width (84, 84)
# <PIL.Image.Image image mode=RGB size=514x514>

# %% [markdown]
# # Keypoints

# %%
Painter.show_keypoints(name_a, level='both', filtered=False)
# Out:
# INFO     | show_keypoints | Number of Keypoints 310
# <PIL.Image.Image image mode=RGB size=504x504>

# %%
Painter.show_keypoints(name_a, level='both', filtered=True)
# Out:
# INFO     | show_keypoints | Number of Keypoints 110
# <PIL.Image.Image image mode=RGB size=504x504>

# %%
Painter.show_keypoints(name_a, level='patch', filtered=False)
# Out:
# INFO     | _show_keypoints | Number of Keypoints 10
# <PIL.Image.Image image mode=RGB size=504x504>

# %%
Painter.show_keypoints(name_a, level='patch', filtered=True)
# Out:
# INFO     | _show_keypoints | Number of Keypoints 10
# <PIL.Image.Image image mode=RGB size=504x504>

# %% [markdown]
# # Matches

# %%
Painter.show_matches(name_a, name_b, num_points=None)
# Out:
# INFO     | show_matches | Number of Matches 253
# <PIL.Image.Image image mode=RGB size=1008x504>

# %%
Painter.show_filtered_matches(name_a, name_b, num_points=None)
# Out:
# INFO     | show_filtered_matches | Number of Matches 87
# <PIL.Image.Image image mode=RGB size=1008x504>
